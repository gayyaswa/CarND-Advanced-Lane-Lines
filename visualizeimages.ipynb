# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

images = glob.glob('output_images/undistorted/*.jpg')
#for fname in images:

img = mpimg.imread('output_images/undistorted/straight_lines1.jpg')

plt.imshow(img)

plt.plot( 820, 500,'.') #top right
plt.plot( 1150, 680, '.') #bottom right
plt.plot( 180, 680, '.') #bottom left
plt.plot( 480, 500, '.' ) #top left

height, width, channels = img.shape
img_size = img.shape

print(height,width)

offset = 100

'''dst = np.float32([[offset, offset], [img_size[0] - offset, offset],
                      [img_size[0] - offset, img_size[1] - offset],
                      [offset, img_size[1] - offset]])

plt.plot( offset, offset,'.') #top right
plt.plot( height-offset, offset, '.') #bottom right
plt.plot( height-offset, width, '.') #bottom left
plt.plot( offset, width-offset, '.' ) #top left'''

'''dst = np.float32(
        [[offset, 0]
        ,[img_height-offset, 0]
        ,[img_height-offset, img_width]
        ,[offset, img_width]
        ]
    )'''
# Out:
# 720 1280
# 'dst = np.float32(\n        [[offset, 0]\n        ,[img_height-offset, 0]\n        ,[img_height-offset, img_width]\n        ,[offset, img_width]\n        ]\n    )'
