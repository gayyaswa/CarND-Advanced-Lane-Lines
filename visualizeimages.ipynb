# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

images = glob.glob('output_images/undistorted/*.jpg')
#for fname in images:

img = mpimg.imread('output_images/undistorted/straight_lines1.jpg')

plt.imshow(img)

plt.plot( 790, 500,'.') #top right
plt.plot( 1075, 680, '.') #bottom right
plt.plot( 220, 680, '.') #bottom left
plt.plot( 480, 500, '.' ) #top left
